# %%
import pickle
import numpy as np
with open('data/embeddings.pkl','rb') as file:
    main_dict = pickle.load(file)

print(np.max([len(val['pep_seq']) for key,val in main_dict.items()]))
# Out:
# 50

# %%
len([val['pep_seq'] for key,val in main_dict.items() if len(val['pep_seq']) == 45])
# Out:
# 9

# %%
df = df.dropna(subset = ['PDB_ID'])
df['PDB_ID'].to_list()
# Out:
# ['None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '1CW5 resolved by NMR.',
#  'None',
#  'None',
#  'None',
#  '2JUI resolved by NMR.',
#  '2RLW resolved by NMR.',
#  '2KHF, 2KHG resolved by NMR.',
#  '2KEG, 2KEH resolved by NMR.',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '1Q71, 1PP5 resolved by NMR.',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '1JKZ resolved by NMR.',
#  'None',
#  'None',
#  '1N4N resolved by NMR.',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '2KHB resolved by NMR.',
#  '1BH4 resolved by NMR.',
#  '2ERI resolved by NMR.',
#  'None',
#  'None',
#  'None',
#  '1C01 resolved by NMR.',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  '2MP9 resolved by NMR.',
#  '2MWT resolved by NMR',
# ...

# %%
import pandas as pd 

df = pd.read_parquet('data/covabdab_binding.parquet')
df.shape
# Out:
# (632, 33)

# %%
import pandas as pd

path = "data/part-00000-3a065afd-b2fa-4875-a6e5-911e95e3f86c-c000.snappy.parquet.crc"

df = pd.read_parquet(path)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[22], line 5
#       1 import pandas as pd
#       3 path = "data/part-00000-3a065afd-b2fa-4875-a6e5-911e95e3f86c-c000.snappy.parquet.crc"
# ----> 5 df = pd.read_parquet(path)
#       6 print(df.head())
#
# File ~/.conda/envs/drug_bind/lib/python3.11/site-packages/pandas/io/parquet.py:503, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     456 """
#     457 Load a parquet object from the file path, returning a DataFrame.
#     458
#    (...)    499 DataFrame
#     500 """
#     501 impl = get_engine(engine)
# --> 503 return impl.read(
#     504     path,
#     505     columns=columns,
#     506     storage_options=storage_options,
#     507     use_nullable_dtypes=use_nullable_dtypes,
#     508     **kwargs,
#     509 )
#
# ...
